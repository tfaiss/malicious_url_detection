# %% [markdown]
# ### Load libraries and read in data

# %%
import pandas as pd
import numpy as np
from urllib.parse import urlparse
from matplotlib import pyplot as plt

# %%
url_df = pd.read_csv("data/malicious_phish.csv")

# %% [markdown]
# ### Exploratory Data Analysis

# %%
# look up first five rows
url_df.head()
url_df
# Out:
#                                                       url        type
# 0                                        br-icloud.com.br    phishing
# 1                     mp3raid.com/music/krizz_kaliko.html      benign
# 2                         bopsecrets.org/rexroth/cr/1.htm      benign
# 3       http://www.garage-pirenne.be/index.php?option=...  defacement
# 4       http://adventure-nicaragua.net/index.php?optio...  defacement
# ...                                                   ...         ...
# 651186            xbox360.ign.com/objects/850/850402.html    phishing
# 651187       games.teamxbox.com/xbox-360/1860/Dead-Space/    phishing
# 651188         www.gamespot.com/xbox360/action/deadspace/    phishing
# 651189      en.wikipedia.org/wiki/Dead_Space_(video_game)    phishing
# 651190          www.angelfire.com/goth/devilmaycrytonite/    phishing
#
# [651191 rows x 2 columns]

# %%
# what's the dimension?
url_df.shape
# Out:
# (651191, 2)

# %%
# replace phishing urls with 1
url_df.loc[url_df['type'] == "phishing", "type"] = 1

# replace malware urls with 1
url_df.loc[url_df['type'] == "malware", "type"] = 1

# replace benign urls with 0
url_df.loc[url_df['type'] == "benign", "type"] = 0

# %%
url_df
# Out:
#                                                       url        type
# 0                                        br-icloud.com.br           1
# 1                     mp3raid.com/music/krizz_kaliko.html           0
# 2                         bopsecrets.org/rexroth/cr/1.htm           0
# 3       http://www.garage-pirenne.be/index.php?option=...  defacement
# 4       http://adventure-nicaragua.net/index.php?optio...  defacement
# ...                                                   ...         ...
# 651186            xbox360.ign.com/objects/850/850402.html           1
# 651187       games.teamxbox.com/xbox-360/1860/Dead-Space/           1
# 651188         www.gamespot.com/xbox360/action/deadspace/           1
# 651189      en.wikipedia.org/wiki/Dead_Space_(video_game)           1
# 651190          www.angelfire.com/goth/devilmaycrytonite/           1
#
# [651191 rows x 2 columns]

# %%
# drop all defacement entries
index_names = url_df[url_df['type'] == "defacement"].index
url_df.drop(index_names, inplace = True)
url_df
# Out:
#                                                       url type
# 0                                        br-icloud.com.br    1
# 1                     mp3raid.com/music/krizz_kaliko.html    0
# 2                         bopsecrets.org/rexroth/cr/1.htm    0
# 5       http://buzzfil.net/m/show-art/ils-etaient-loin...    0
# 6           espn.go.com/nba/player/_/id/3457/brandon-rush    0
# ...                                                   ...  ...
# 651186            xbox360.ign.com/objects/850/850402.html    1
# 651187       games.teamxbox.com/xbox-360/1860/Dead-Space/    1
# 651188         www.gamespot.com/xbox360/action/deadspace/    1
# 651189      en.wikipedia.org/wiki/Dead_Space_(video_game)    1
# 651190          www.angelfire.com/goth/devilmaycrytonite/    1
#
# [554734 rows x 2 columns]

# %%
def createTokens(url):
    scheme =

# %%
df2 = url_df.copy()

# %%
#list(df2['url'].head())

# %%
url_parsed = []
results = []
results_netloc = []

for i in list(df2['url']):
    url_parsed = urlparse(i)
    #print ("-----")
    #print(i)
    #print("Scheme: " + url_parsed.scheme)
    #print("Domain: " + url_parsed.netloc)
    #print("Host: " + str(url_parsed.hostname))
    #print("Folder: " + url_parsed.path)
    #print("Params: " + url_parsed.params)
    #print("Query: " + url_parsed.query)
    #print("------")
    
    #df2['scheme'] = url_parsed.scheme
    #df2['domain'] = url_parsed.netloc
    #df2['host'] = url_parsed.hostname
    #df2['folder'] = url_parsed.path
    #df2['params'] = url_parsed.params
    #df2['query'] = url_parsed.query
    
    if url_parsed.scheme == "http":
        results.append("http")
    elif url_parsed.scheme == "https":
        results.append("https")
    else:
        results.append("Null")
    
    
    
    if url_parsed.netloc != "":
        results_netloc.append(url_parsed.netloc)
    else:
        results_netloc.append("Null")
    
#results    
    
df2['scheme'] = results
df2['netloc'] = results_netloc


df2
# Out:
#                                                       url type scheme  \
# 0                                        br-icloud.com.br    1   Null
# 1                     mp3raid.com/music/krizz_kaliko.html    0   Null
# 2                         bopsecrets.org/rexroth/cr/1.htm    0   Null
# 5       http://buzzfil.net/m/show-art/ils-etaient-loin...    0   http
# 6           espn.go.com/nba/player/_/id/3457/brandon-rush    0   Null
# ...                                                   ...  ...    ...
# 651186            xbox360.ign.com/objects/850/850402.html    1   Null
# 651187       games.teamxbox.com/xbox-360/1860/Dead-Space/    1   Null
# 651188         www.gamespot.com/xbox360/action/deadspace/    1   Null
# 651189      en.wikipedia.org/wiki/Dead_Space_(video_game)    1   Null
# 651190          www.angelfire.com/goth/devilmaycrytonite/    1   Null
#
#              netloc
# 0              Null
# 1              Null
# 2              Null
# 5       buzzfil.net
# ...

# %%
url_array = url_df[['url','type']].to_numpy()

# %%
# show entire array
url_array
# Out:
# array([['br-icloud.com.br', 1],
#        ['mp3raid.com/music/krizz_kaliko.html', 0],
#        ['bopsecrets.org/rexroth/cr/1.htm', 0],
#        ...,
#        ['www.gamespot.com/xbox360/action/deadspace/', 1],
#        ['en.wikipedia.org/wiki/Dead_Space_(video_game)', 1],
#        ['www.angelfire.com/goth/devilmaycrytonite/', 1]], dtype=object)

# %%
url_parsed = []
for i in url_array[:,0]:
    url_parsed = url_parsed + list(urlparse(i))
    
url_parsed

# %%
for i in url_array[:,0]:
    url_parsed = urlparse(i)
    print (url_parsed)

# %%
# create array
arr = np.array([1, 2, 4, 5])
print("Before conversion: ", arr)
print(type(arr))
 
# Converting numpy to list
arr = list(arr)
print("\nAfter conversion: ", type(arr))
print(arr)

# %%
for i in urls.all():
    url_parsed = urlparse(i)
    print("Scheme: " + url_parsed.scheme)
    print("Domain: " + url_parsed.netloc)
    print("Hostname: " + str(url_parsed.hostname))
    print("Folder: " + url_parsed.path)
    print("Port: " + str(url_parsed.port))
    print("Params: " + url_parsed.params)
    print("Query: " + url_parsed.query)
    print("------")
    #print("Malicious: " + )
    print("------")
